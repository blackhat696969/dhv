# %% [markdown]
# # Time Series With Trend

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={"Date": pd.to_datetime(["2022-01-01","2022-02-01","2022-03-01","2022-04-01","2022-05-01","2022-06-01",
              "2022-07-01","2022-08-01","2022-09-01","2022-10-01","2022-11-01","2022-12-01","2023-01-01","2023-02-01","2023-03-01"]),

      "Value": [10, 15,22, 28, 35, 42, 48, 55, 60, 68, 75, 82, 90, 98, 105]
      }
df = pd.DataFrame(data)
df.set_index("Date", inplace=True)
plt.figure(figsize=(10,6))
plt.plot(df.index, df["Value"],marker='o')
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("Time Series With Trend")
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Time Series With  Trend Seasonality**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={"Date": pd.to_datetime(["2022-01-01","2022-02-01","2022-03-01","2022-04-01","2022-05-01","2022-06-01",
              "2022-07-01","2022-08-01","2023-02-01","2023-03-01"]),

      "Value": [10, 15,42, 34, 64,  62, 55, 40, 68, 50]
      }
df = pd.DataFrame(data)
df.set_index("Date", inplace=True)
plt.figure(figsize=(10,6))
plt.plot(df.index, df["Value"],marker='o')
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("Time Series With Seasonality")
plt.grid(True)
plt.show()

# %% [markdown]
# ## time series with seasonality and trend

# %%
import pandas as pd

data_orig = pd.read_csv('/content/drive/MyDrive/dhruv dataset/quebec_real_estate.csv')

data_orig['Date'] = pd.to_datetime(data_orig['Date']) # convert date column to DateTime
x = data_orig.plot(x='Date', y='Montreal_Median_Price', figsize=(12,6))

# %% [markdown]
# time series with trend

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/dhruv dataset/multiTimeline.csv')
gym = df[['Gym']]
gym.rolling(12).mean().plot(figsize=(10,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %% [markdown]
# time series with seasonality

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
diet = df[['Diet']]
diet.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);
